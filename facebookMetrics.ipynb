# %%
import pandas as pd

# %%
df = pd.read_csv("facebook.csv", sep=';');
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df1 = df[['Type','Category']]
df1
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %%
df2 = df.iloc[3:6,1:8]
df2
# Out:
#      Type  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 3   Photo         2          12             2         10   1.0
# 4   Photo         2          12             2          3   0.0
# 5  Status         2          12             1          9   0.0
#
#    Lifetime Post Total Reach
# 3                      50128
# 4                       7244
# 5                      10472

# %%
df3 = df.loc[1:5]
df3
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 5   0.0                      10472                            20849
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df4 = df.iloc[:,1:8]
df4
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0     Photo         2          12             4          3   0.0
# 1    Status         2          12             3         10   0.0
# 2     Photo         3          12             3          3   0.0
# 3     Photo         2          12             2         10   1.0
# 4     Photo         2          12             2          3   0.0
# ..      ...       ...         ...           ...        ...   ...
# 495   Photo         3           1             7          2   0.0
# 496   Photo         2           1             5          8   0.0
# 497   Photo         1           1             5          2   0.0
# 498   Photo         3           1             4         11   0.0
# 499   Photo         2           1             4          4   NaN
#
#      Lifetime Post Total Reach
# 0                         2752
# 1                        10460
# 2                         2413
# 3                        50128
# ...

# %%
df[df['Type'] == 'Photo']
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
df4.sort_values(by="Post Month",ascending=False)
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0     Photo         2          12             4          3   0.0
# 38   Status         2          12             7          9   0.0
# 28    Photo         2          12             5          3   0.0
# 29    Video         1          12             4         11   1.0
# 30    Photo         2          12             4          2   0.0
# ..      ...       ...         ...           ...        ...   ...
# 478   Photo         3           1             5         13   0.0
# 477    Link         1           1             6          4   0.0
# 476   Photo         1           1             6         10   1.0
# 475   Photo         3           1             6         16   1.0
# 499   Photo         2           1             4          4   NaN
#
#      Lifetime Post Total Reach
# 0                         2752
# 38                       17576
# 28                        9560
# 29                       36208
# ...

# %%
df4.sort_values(by=["Post Month","Post Hour"],ascending=False)
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 17    Photo         1          12             2         12   1.0
# 19    Photo         3          12             1         11   0.0
# 26   Status         2          12             5         11   0.0
# 29    Video         1          12             4         11   1.0
# 35    Photo         2          12             1         11   0.0
# ..      ...       ...         ...           ...        ...   ...
# 487   Photo         3           1             1          2   0.0
# 489   Photo         3           1             7          2   0.0
# 493   Photo         3           1             1          2   0.0
# 495   Photo         3           1             7          2   0.0
# 497   Photo         1           1             5          2   0.0
#
#      Lifetime Post Total Reach
# 17                       53264
# 19                        1591
# 26                       19552
# 29                       36208
# ...

# %%
pd.merge(df1,df2, on='Type', how='outer')
# Out:
#       Type  Category_x  Category_y  Post Month  Post Weekday  Post Hour  Paid  \
# 0    Photo           2         2.0        12.0           2.0       10.0   1.0
# 1    Photo           2         2.0        12.0           2.0        3.0   0.0
# 2    Photo           3         2.0        12.0           2.0       10.0   1.0
# 3    Photo           3         2.0        12.0           2.0        3.0   0.0
# 4    Photo           2         2.0        12.0           2.0       10.0   1.0
# ..     ...         ...         ...         ...           ...        ...   ...
# 921  Video           1         NaN         NaN           NaN        NaN   NaN
# 922  Video           1         NaN         NaN           NaN        NaN   NaN
# 923  Video           1         NaN         NaN           NaN        NaN   NaN
# 924  Video           1         NaN         NaN           NaN        NaN   NaN
# 925  Video           1         NaN         NaN           NaN        NaN   NaN
#
#      Lifetime Post Total Reach
# ...

# %%
pd.merge(df1,df2, on='Type', how='left')
# Out:
#        Type  Category_x  Category_y  Post Month  Post Weekday  Post Hour  \
# 0     Photo           2         2.0        12.0           2.0       10.0
# 1     Photo           2         2.0        12.0           2.0        3.0
# 2    Status           2         2.0        12.0           1.0        9.0
# 3     Photo           3         2.0        12.0           2.0       10.0
# 4     Photo           3         2.0        12.0           2.0        3.0
# ..      ...         ...         ...         ...           ...        ...
# 921   Photo           1         2.0        12.0           2.0        3.0
# 922   Photo           3         2.0        12.0           2.0       10.0
# 923   Photo           3         2.0        12.0           2.0        3.0
# 924   Photo           2         2.0        12.0           2.0       10.0
# 925   Photo           2         2.0        12.0           2.0        3.0
#
#      Paid  Lifetime Post Total Reach
# 0     1.0                    50128.0
# ...

# %%
pd.merge(df1,df2, on='Type', how='right')
# Out:
#        Type  Category_x  Category_y  Post Month  Post Weekday  Post Hour  \
# 0     Photo           2           2          12             2         10
# 1     Photo           3           2          12             2         10
# 2     Photo           2           2          12             2         10
# 3     Photo           2           2          12             2         10
# 4     Photo           3           2          12             2         10
# ..      ...         ...         ...         ...           ...        ...
# 892  Status           2           2          12             1          9
# 893  Status           1           2          12             1          9
# 894  Status           2           2          12             1          9
# 895  Status           2           2          12             1          9
# 896  Status           1           2          12             1          9
#
#      Paid  Lifetime Post Total Reach
# 0     1.0                      50128
# ...

# %%
pd.merge(df1,df2, on='Type', how='inner')
# Out:
#        Type  Category_x  Category_y  Post Month  Post Weekday  Post Hour  \
# 0     Photo           2           2          12             2         10
# 1     Photo           2           2          12             2          3
# 2     Photo           3           2          12             2         10
# 3     Photo           3           2          12             2          3
# 4     Photo           2           2          12             2         10
# ..      ...         ...         ...         ...           ...        ...
# 892  Status           2           2          12             1          9
# 893  Status           1           2          12             1          9
# 894  Status           2           2          12             1          9
# 895  Status           2           2          12             1          9
# 896  Status           1           2          12             1          9
#
#      Paid  Lifetime Post Total Reach
# 0     1.0                      50128
# ...

# %%
pd.concat([df1,df2],axis=0,ignore_index = True)
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0     Photo         2         NaN           NaN        NaN   NaN
# 1    Status         2         NaN           NaN        NaN   NaN
# 2     Photo         3         NaN           NaN        NaN   NaN
# 3     Photo         2         NaN           NaN        NaN   NaN
# 4     Photo         2         NaN           NaN        NaN   NaN
# ..      ...       ...         ...           ...        ...   ...
# 498   Photo         3         NaN           NaN        NaN   NaN
# 499   Photo         2         NaN           NaN        NaN   NaN
# 500   Photo         2        12.0           2.0       10.0   1.0
# 501   Photo         2        12.0           2.0        3.0   0.0
# 502  Status         2        12.0           1.0        9.0   0.0
#
#      Lifetime Post Total Reach
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# ...

# %%
df2.transpose()
# Out:
#                                3      4       5
# Type                       Photo  Photo  Status
# Category                       2      2       2
# Post Month                    12     12      12
# Post Weekday                   2      2       1
# Post Hour                     10      3       9
# Paid                         1.0    0.0     0.0
# Lifetime Post Total Reach  50128   7244   10472

# %%
df2.shape
# Out:
# (3, 7)

# %%
df6 = df.iloc[:3,:3]
df6
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 2            139441   Photo         3

# %%
df6.pivot(index='Type',columns='Category')
# Out:
#          Page total likes
# Category                2         3
# Type
# Photo            139441.0  139441.0
# Status           139441.0       NaN

# %%
df7 = df.iloc[0:4,:4]
df7
# Out:
#    Page total likes    Type  Category  Post Month
# 0            139441   Photo         2          12
# 1            139441  Status         2          12
# 2            139441   Photo         3          12
# 3            139441   Photo         2          12

# %%
df7.melt(id_vars='Type')
# Out:
#       Type          variable   value
# 0    Photo  Page total likes  139441
# 1   Status  Page total likes  139441
# 2    Photo  Page total likes  139441
# 3    Photo  Page total likes  139441
# 4    Photo          Category       2
# 5   Status          Category       2
# 6    Photo          Category       3
# 7    Photo          Category       2
# 8    Photo        Post Month      12
# 9   Status        Post Month      12
# 10   Photo        Post Month      12
# 11   Photo        Post Month      12
